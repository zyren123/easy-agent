# %% [markdown]
# # 01 Linear Layer
#
# This notebook mirrors `lesson.py` and will become the interactive version of the first lesson.

# %%
from ai_edu.foundations import LinearLayerLesson

# %%
LinearLayerLesson().module_path()
